# %%
import requests
import pandas as pd

def fetch_arrest_data(start_date, end_date):
    url = "https://data.cityofnewyork.us/resource/8h9b-rp9u.json"
    params = {
        "$where": f"arrest_date between '{start_date}' and '{end_date}'",
        "$limit": 10000  # Adjust as necessary
    }
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        return pd.DataFrame(response.json())
    except requests.RequestException as e:
        print(f"Error fetching data: {e}")
        return pd.DataFrame()
fetch_arrest_data('2018-01-01', '2018-01-30')
# Out:
#      arrest_key              arrest_date pd_cd  \
# 0     173151555  2018-01-01T00:00:00.000   109
# 1     173148126  2018-01-01T00:00:00.000   531
# 2     173142262  2018-01-01T00:00:00.000   113
# 3     173142129  2018-01-01T00:00:00.000   904
# 4     173142152  2018-01-01T00:00:00.000   101
# ...         ...                      ...   ...
# 9995  173636346  2018-01-15T00:00:00.000   478
# 9996  173636326  2018-01-15T00:00:00.000   849
# 9997  173652876  2018-01-15T00:00:00.000   503
# 9998  173646987  2018-01-15T00:00:00.000   782
# 9999  173646764  2018-01-15T00:00:00.000   750
#
#                                          pd_desc ky_cd  \
# 0                       ASSAULT 2,1,UNCLASSIFIED   106
# 1     DRUG PARAPHERNALIA,   POSSESSES OR SELLS 1   117
# 2                          MENACING,UNCLASSIFIED   344
# 3                    INTOXICATED DRIVING,ALCOHOL   119
# 4                                      ASSAULT 3   344
# ...                                          ...   ...
# 9995             THEFT OF SERVICES, UNCLASSIFIED   343
# 9996        NY STATE LAWS,UNCLASSIFIED VIOLATION   677
# 9997       CONTROLLED SUBSTANCE,INTENT TO SELL 3   117
# 9998                    WEAPONS, POSSESSION, ETC   236
# 9999                            RESISTING ARREST   359
#
#                                    ofns_desc    law_code law_cat_cd  \
# 0                             FELONY ASSAULT  PL 1201001          F
# 1                            DANGEROUS DRUGS  PL 2205500          F
# 2               ASSAULT 3 & RELATED OFFENSES  PL 1201401          M
# 3               INTOXICATED/IMPAIRED DRIVING  VTL11920D3          F
# 4               ASSAULT 3 & RELATED OFFENSES  PL 1200001          M
# ...                                      ...         ...        ...
# 9995         OTHER OFFENSES RELATED TO THEFT  PL 1651503          M
# 9996                        OTHER STATE LAWS  LOC000000V          V
# 9997                         DANGEROUS DRUGS  PL 2201601          F
# 9998                       DANGEROUS WEAPONS  PL 2650101          M
# 9999  OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 2053000          M
#
#      arrest_boro arrest_precinct jurisdiction_code age_group perp_sex  \
# 0              K              66                 0     25-44        M
# 1              M              17                97     25-44        F
# 2              S             121                 0       <18        F
# 3              B              40                 2     45-64        M
# 4              B              46                 0     18-24        M
# ...          ...             ...               ...       ...      ...
# 9995           M              14                 1     25-44        M
# 9996           K              61                 0     45-64        M
# 9997           S             120                 0     25-44        F
# 9998           Q             114                 0     18-24        M
# 9999           M              14                 7     25-44        M
#
#                      perp_race x_coord_cd y_coord_cd            latitude  \
# 0     ASIAN / PACIFIC ISLANDER     986735     167242   40.62572501600005
# 1                        BLACK     992029     213332  40.752228400000035
# 2                        BLACK     939367     169549   40.63194388100004
# 3               BLACK HISPANIC    1006777     236405   40.81553235500007
# 4               BLACK HISPANIC    1008861     247665   40.84643225400004
# ...                        ...        ...        ...                 ...
# 9995            WHITE HISPANIC     987636     212439   40.74978011300004
# 9996  ASIAN / PACIFIC ISLANDER     995683     155709  40.594062270000045
# 9997                     BLACK     962605     167032   40.62512251400005
# 9998            WHITE HISPANIC    1011808     218940   40.76758139700007
# 9999                     BLACK     986320     212857   40.75092782300004
#
#                longitude                                            lon_lat
# 0     -73.99104937999994  {'type': 'Point', 'coordinates': [-73.99104937...
# 1     -73.97192485799998  {'type': 'Point', 'coordinates': [-73.97192485...
# 2     -74.16170488099993  {'type': 'Point', 'coordinates': [-74.16170488...
# 3     -73.91861784599996  {'type': 'Point', 'coordinates': [-73.91861784...
# 4     -73.91104764699998  {'type': 'Point', 'coordinates': [-73.91104764...
# ...                  ...                                                ...
# 9995  -73.98778087399995  {'type': 'Point', 'coordinates': [-73.98778087...
# 9996  -73.95883427899997  {'type': 'Point', 'coordinates': [-73.95883427...
# 9997  -74.07797554499997  {'type': 'Point', 'coordinates': [-74.07797554...
# 9998  -73.90051395299997  {'type': 'Point', 'coordinates': [-73.90051395...
# 9999  -73.99253038399996  {'type': 'Point', 'coordinates': [-73.99253038...
#
# [10000 rows x 19 columns]
